# %%
import pandas as pd
customer=pd.read_csv("C:/Users/YogeshwaranAnnadurai/Downloads/customers-1000.csv") 
customer.shape
rows,columns=customer.shape

customer.head(11)
customer.drop(columns=["Phone 2","Website"])
print("NO.of rows=",rows)
print("NO.of columns=",columns)
# Out:
# NO.of rows= 1000
# NO.of columns= 12

# %%
customer.head(11)
customer.drop(columns=["Phone 2","Website"])
# Out:
#      Index      Customer Id First Name Last Name                      Company  \
# 0        1  dE014d010c7ab0c     Andrew   Goodman                Stewart-Flynn
# 1        2  2B54172c8b65eC3      Alvin      Lane  Terry, Proctor and Lawrence
# 2        3  d794Dd48988d2ac      Jenna   Harding                 Bailey Group
# 3        4  3b3Aa4aCc68f3Be   Fernando      Ford                 Moss-Maxwell
# 4        5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
# ..     ...              ...        ...       ...                          ...
# 995    996  FbcCaF483aFaFAE      Diana    Monroe                  Bass-Wilson
# 996    997  979c4D58Ae9a9cc      Jerry   Morales                   Pratt-King
# 997    998  D0DcF6a4BcefCc8     Tracie     Floyd     Holt, Wilson and Shields
# 998    999  90EE9CbbDa374E9       Paul    Barnes     Brown, Oliver and Haynes
# 999   1000  51732B5b2328015    Dominic     Duran                   Durham LLC
#
# ...

# %%
customer.sample(frac=0.5 )
# Out:
#      Index      Customer Id First Name Last Name  \
# 303    304  4a219E8afe2F6cb       Jade    Archer
# 636    637  3b480808b1Db3d8     Norman    Howard
# 712    713  1C1Dacf3d47eb8e     Briana     Davis
# 58      59  b78002FEFF5a860   Jennifer   Fleming
# 225    226  67b2CF189EcFb5b      Lacey      Bond
# ..     ...              ...        ...       ...
# 959    960  dc9c71CeFaCBfc7      Molly    Prince
# 114    115  d3905aAEeB7eF7b      Pedro    Franco
# 235    236  eF2fec28b643Ecc     Hannah      Beck
# 961    962  a59571eD1ebab1B  Alejandra   Harding
# 697    698  D0db4FaD1ce14Ef      Grant   Mercado
#
#                            Company              City  \
# 303      Fischer, Vang and Skinner        Berrymouth
# 636             Carpenter and Sons         Tammyberg
# 712                    Stone-Floyd    Castanedamouth
# 58               Schaefer-Chambers      Shepherdfort
# 225                  Dougherty-Day        Grantshire
# ...

# %%
customer.sample(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 customer.sample(10)
#
# NameError: name 'customer' is not defined

# %%
customer.nsmallest(1,'Index')
# Out:
#    Index      Customer Id First Name Last Name        Company         City  \
# 0      1  dE014d010c7ab0c     Andrew   Goodman  Stewart-Flynn  Rowlandberg
#
#   Country            Phone 1              Phone 2  \
# 0   Macao  846-790-4623x4715  (422)787-2331x71127
#
#                            Email Subscription Date               Website
# 0  marieyates@gomez-spencer.info        26-07-2021  http://www.shea.biz/

# %%
# Out:
# Index                                     1000
# Customer Id                    ffc96A6EDB33EFf
# First Name                                 Zoe
# Last Name                                Zhang
# Company                        Zhang-Stevenson
# City                                   Zoefurt
# Country                               Zimbabwe
# Phone 1                           999.090.5244
# Phone 2                     998-357-1638x25087
# Email                zturner@jimenez-wells.biz
# Subscription Date                   31-12-2021
# Website                     https://zhang.org/
# dtype: object
