# %%
import pandas as yogesh
Demo=yogesh.read_csv("C:/Users/YogeshwaranAnnadurai/Documents/Book3.csv")
# Demo.shape
# rows , columns = Demo.shape
# print("NO.of Rows=",rows)
# print("No.of column=",columns)

# %%
Demo
# Out:
#     YearofStudy                    Course  Age  ApproxHeight  ApproxWeight  \
# 0   Second Year               MATHEMATICS   20           152            80
# 1    First Year  ECONOMICS AND STATISTICS   29           182            79
# 2   Fourth Year               MATHEMATICS   22           167            64
# 3   Second Year  ECONOMICS AND STATISTICS   23           149            52
# 4   Second Year               MATHEMATICS   18           150            70
# 5    Third Year            URBAN PLANNING   20           154            56
# 6    Third Year               MATHEMATICS   21           165            79
# 7    Third Year               MATHEMATICS   21           162            57
# 8   Fourth Year         ACTUARIAL SCIENCE   22           154            53
# 9   Fourth Year                 ECONOMICS   21           172            57
# 10   Third Year               MATHEMATICS   22           172            78
# ...

# %%
import pandas as yogesh
GRADE=yogesh.read_csv("C:/Users/YogeshwaranAnnadurai/Documents/std2.csv")

# %%
Demo
# Out:
#     YearofStudy                    Course  Age  ApproxHeight  ApproxWeight  \
# 0   Second Year               MATHEMATICS   20           152            80
# 1    First Year  ECONOMICS AND STATISTICS   29           182            79
# 2   Fourth Year               MATHEMATICS   22           167            64
# 3   Second Year  ECONOMICS AND STATISTICS   23           149            52
# 4   Second Year               MATHEMATICS   18           150            70
# 5    Third Year            URBAN PLANNING   20           154            56
# 6    Third Year               MATHEMATICS   21           165            79
# 7    Third Year               MATHEMATICS   21           162            57
# 8   Fourth Year         ACTUARIAL SCIENCE   22           154            53
# 9   Fourth Year                 ECONOMICS   21           172            57
# 10   Third Year               MATHEMATICS   22           172            78
# ...

# %%
Demo["NewHead"]=1
GRADE["NewHead"]=2

# %%
Demo.head(5)
# Out:
#    YearofStudy                    Course  Age  ApproxHeight  ApproxWeight  \
# 0  Second Year               MATHEMATICS   20           152            80
# 1   First Year  ECONOMICS AND STATISTICS   29           182            79
# 2  Fourth Year               MATHEMATICS   22           167            64
# 3  Second Year  ECONOMICS AND STATISTICS   23           149            52
# 4  Second Year               MATHEMATICS   18           150            70
#
#    KCSE  NewHead
# 0  2016        1
# 1  2010        1
# 2  2015        1
# 3  2016        1
# 4  2013        1

# %%
GRADE.head(5)
# Out:
#    YearofStudy                  Course  Age  ApproxHeight  ApproxWeight  KCSE  \
# 0   Third Year              STATISTICS   21           161            77  2015
# 1   Third Year             MATHEMATICS   22           168            61  2016
# 2  Second Year       ACTUARIAL SCIENCE   24           157            63  2017
# 3   Third Year  ELECTRICAL ENGINEERING   23           144            54  2016
# 4  Second Year             MATHEMATICS   21           141            75  2016
#
#    NewHead
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2

# %%
CON=yogesh.concat([Demo,GRADE])

# %%
CON=yogesh.concat([Demo.head(5),GRADE.head(5)])

# %%
CON
# Out:
#    YearofStudy                    Course  Age  ApproxHeight  ApproxWeight  \
# 0  Second Year               MATHEMATICS   20           152            80
# 1   First Year  ECONOMICS AND STATISTICS   29           182            79
# 2  Fourth Year               MATHEMATICS   22           167            64
# 3  Second Year  ECONOMICS AND STATISTICS   23           149            52
# 4  Second Year               MATHEMATICS   18           150            70
# 0   Third Year                STATISTICS   21           161            77
# 1   Third Year               MATHEMATICS   22           168            61
# 2  Second Year         ACTUARIAL SCIENCE   24           157            63
# 3   Third Year    ELECTRICAL ENGINEERING   23           144            54
# 4  Second Year               MATHEMATICS   21           141            75
#
#    KCSE
# 0  2016
# 1  2010
# 2  2015
# 3  2016
# 4  2013
# 0  2015
# 1  2016
# 2  2017
# 3  2016
# 4  2016

# %%
CON.sort_index()
# Out:
#    YearofStudy                    Course  Age  ApproxHeight  ApproxWeight  \
# 0  Second Year               MATHEMATICS   20           152            80
# 0   Third Year                STATISTICS   21           161            77
# 1   First Year  ECONOMICS AND STATISTICS   29           182            79
# 1   Third Year               MATHEMATICS   22           168            61
# 2  Fourth Year               MATHEMATICS   22           167            64
# 2  Second Year         ACTUARIAL SCIENCE   24           157            63
# 3  Second Year  ECONOMICS AND STATISTICS   23           149            52
# 3   Third Year    ELECTRICAL ENGINEERING   23           144            54
# 4  Second Year               MATHEMATICS   18           150            70
# 4  Second Year               MATHEMATICS   21           141            75
#
#    KCSE
# 0  2016
# 0  2015
# 1  2010
# 1  2016
# 2  2015
# 2  2017
# 3  2016
# 3  2016
# 4  2013
# 4  2016

# %%
data ={'Course':['MATHEMATICS','ECONOMICS AND STATISTICS','STATISTICS','ACTUARIAL SCIENCE'],
      'Age': [20,29,22,18]} 
DF=yogesh.DataFrame(data)
filtering=DF[(DF['Course']== "ECONOMICS AND STATISTICS")]
print(filtering)
# Out:
#                      Course  Age
# 1  ECONOMICS AND STATISTICS   29

# %% [markdown]
# & = AND

# %%
DF=yogesh.DataFrame(CON)
# filtering=DF[(DF['Course']== "ECONOMICS AND STATISTICS")]
# filtering=DF[(DF['Age']< 25)]
filtering=DF[(DF['ApproxWeight']>60) & (DF['Age']< 25)]  
print(filtering)
# Out:
#    YearofStudy             Course  Age  ApproxHeight  ApproxWeight  KCSE  \
# 0  Second Year        MATHEMATICS   20           152            80  2016
# 2  Fourth Year        MATHEMATICS   22           167            64  2015
# 4  Second Year        MATHEMATICS   18           150            70  2013
# 0   Third Year         STATISTICS   21           161            77  2015
# 1   Third Year        MATHEMATICS   22           168            61  2016
# 2  Second Year  ACTUARIAL SCIENCE   24           157            63  2017
# 4  Second Year        MATHEMATICS   21           141            75  2016
#
#    NewHead
# 0        1
# 2        1
# 4        1
# 0        2
# 1        2
# 2        2
# 4        2

# %% [markdown]
# |=OR

# %%
filtering=DF[(DF['ApproxWeight']>60) | (DF['Age']< 25)] 
print(filtering)
# Out:
#    YearofStudy                    Course  Age  ApproxHeight  ApproxWeight  \
# 0  Second Year               MATHEMATICS   20           152            80
# 1   First Year  ECONOMICS AND STATISTICS   29           182            79
# 2  Fourth Year               MATHEMATICS   22           167            64
# 3  Second Year  ECONOMICS AND STATISTICS   23           149            52
# 4  Second Year               MATHEMATICS   18           150            70
# 0   Third Year                STATISTICS   21           161            77
# 1   Third Year               MATHEMATICS   22           168            61
# 2  Second Year         ACTUARIAL SCIENCE   24           157            63
# 3   Third Year    ELECTRICAL ENGINEERING   23           144            54
# 4  Second Year               MATHEMATICS   21           141            75
#
#    KCSE  NewHead
# 0  2016        1
# 1  2010        1
# 2  2015        1
# 3  2016        1
# 4  2013        1
# 0  2015        2
# 1  2016        2
# ...

# %%
DF.rename(columns={"ApproxWeight":"Weight"})
# Out:
#    YearofStudy                    Course  Age  ApproxHeight  Weight  KCSE  \
# 0  Second Year               MATHEMATICS   20           152      80  2016
# 1   First Year  ECONOMICS AND STATISTICS   29           182      79  2010
# 2  Fourth Year               MATHEMATICS   22           167      64  2015
# 3  Second Year  ECONOMICS AND STATISTICS   23           149      52  2016
# 4  Second Year               MATHEMATICS   18           150      70  2013
# 0   Third Year                STATISTICS   21           161      77  2015
# 1   Third Year               MATHEMATICS   22           168      61  2016
# 2  Second Year         ACTUARIAL SCIENCE   24           157      63  2017
# 3   Third Year    ELECTRICAL ENGINEERING   23           144      54  2016
# 4  Second Year               MATHEMATICS   21           141      75  2016
#
#    NewHead
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2

# %%
CON
# Out:
#    YearofStudy                    Course  Age  ApproxHeight  ApproxWeight  \
# 0  Second Year               MATHEMATICS   20           152            80
# 1   First Year  ECONOMICS AND STATISTICS   29           182            79
# 2  Fourth Year               MATHEMATICS   22           167            64
# 3  Second Year  ECONOMICS AND STATISTICS   23           149            52
# 4  Second Year               MATHEMATICS   18           150            70
# 0   Third Year                STATISTICS   21           161            77
# 1   Third Year               MATHEMATICS   22           168            61
# 2  Second Year         ACTUARIAL SCIENCE   24           157            63
# 3   Third Year    ELECTRICAL ENGINEERING   23           144            54
# 4  Second Year               MATHEMATICS   21           141            75
#
#    KCSE
# 0  2016
# 1  2010
# 2  2015
# 3  2016
# 4  2013
# 0  2015
# 1  2016
# 2  2017
# 3  2016
# 4  2016

# %%
Demo
# Out:
#     YearofStudy                    Course  Age  ApproxHeight  ApproxWeight  \
# 0   Second Year               MATHEMATICS   20           152            80
# 1    First Year  ECONOMICS AND STATISTICS   29           182            79
# 2   Fourth Year               MATHEMATICS   22           167            64
# 3   Second Year  ECONOMICS AND STATISTICS   23           149            52
# 4   Second Year               MATHEMATICS   18           150            70
# 5    Third Year            URBAN PLANNING   20           154            56
# 6    Third Year               MATHEMATICS   21           165            79
# 7    Third Year               MATHEMATICS   21           162            57
# 8   Fourth Year         ACTUARIAL SCIENCE   22           154            53
# 9   Fourth Year                 ECONOMICS   21           172            57
# 10   Third Year               MATHEMATICS   22           172            78
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [YearofStudy, Course, Age, ApproxHeight, ApproxWeight, KCSE]
# Index: []
